# %%
import pandas as pd

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
df = pd.read_csv("/home/ankurghoshal/Projects/projects/ML_Project_2/data/raw/customer_churn_dataset-testing-master.csv")

# %%
from src.components.data_transformation import DataTransformation
dt = DataTransformation()
X_train, X_test, y_train, y_test = dt.initiate_data_transformation(df)

# %%
from src.components.model_trainer import ModelTrainer

trainer = ModelTrainer()
best_model_name, best_recall = trainer.train_and_evaluate(
    X_train, y_train, X_test, y_test
)
# Out:
# Training LogisticRegression...
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      6793
#            1       0.82      0.83      0.82      6082
#
#     accuracy                           0.83     12875
#    macro avg       0.83      0.83      0.83     12875
# weighted avg       0.83      0.83      0.83     12875
#
#
# Training RandomForest...
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6793
#            1       1.00      1.00      1.00      6082
#
#     accuracy                           1.00     12875
#    macro avg       1.00      1.00      1.00     12875
# weighted avg       1.00      1.00      1.00     12875
#
#
# Best Model: RandomForest
# Best Recall: 0.9978625452153896
